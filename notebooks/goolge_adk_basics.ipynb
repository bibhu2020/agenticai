# %% [markdown]
# ## Google ADK

# %% [markdown]
# Agentic systems run automatically, make decission, reasoning and proactive actions to achieve goals in dynamics environment wothout human supervision.
#
# Components of Agentics System:
# - Agent
# - Context
# - Tool
# - Memory (needed for long-live tasks)
# - LLM
# - Prompts

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True
